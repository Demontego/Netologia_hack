# %% [markdown]
# # Step 0.0. Install LightAutoML

# %% [markdown]
# # Step 0.1. Import necessary libraries

# %%
# %matplotlib inline

# Standard python libraries
import os
import time
import re

# Installed libraries
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score, roc_auc_score, recall_score, precision_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# Imports from our package
from lightautoml.automl.presets.tabular_presets import TabularAutoML, TabularUtilizedAutoML
from lightautoml.tasks import Task
from scipy.signal import argrelmax,peak_prominences, find_peaks_cwt, peak_widths, peak_prominences, find_peaks
from lightautoml.dataset.roles import DatetimeRole

# %% [markdown]
# # Step 0.2. Parameters

# %%
N_THREADS = 6 # threads cnt for lgbm and linear models
N_FOLDS = 5 # folds cnt for AutoML
RANDOM_STATE = 777 # fixed random state for various reasons
TEST_SIZE = 0.1 # Test size for metric check
TIMEOUT = 3600*6 # Time in seconds for automl run
TARGET = ['target']

# %% [markdown]
# # Step 0.3. Fix torch number of threads and numpy seed

# %%
np.random.seed(RANDOM_STATE)

# %% [markdown]
# # Step 0.4. Data load

# %%
# %%time

train = pd.read_csv('train_dataset_train.csv', parse_dates=['month_id','carts_created_at'], index_col='id')
print(train.shape)
train.head()
# Out:
# (200000, 58)
# Wall time: 814 ms
#         age_indicator   month_id  student_id  program_id carts_created_at  \
# id
# 15182            32.0 2020-09-30     6694527        1469       2020-08-26
# 89385             NaN 2021-06-30     6712877        1392       2020-08-05
# 47931             NaN 2021-02-28     6659444         376       2020-06-20
# 279085            1.0 2021-11-30     7151591        1160       2021-04-14
# 7806             30.0 2020-10-31     6705666         952       2020-07-19
#
#         spent_time_total  spent_time_to_complete_hw  completed_hw  failed_hw  \
# id
# 15182              163.0                        0.0           1.0        0.0
# 89385                NaN                        NaN           NaN        NaN
# 47931                NaN                        NaN           NaN        NaN
# 279085               NaN                        NaN           NaN        NaN
# 7806                 NaN                        NaN           NaN        NaN
#
#         reworked_hw  ...  p_total_calls  p_was_conversations  \
# id                   ...
# 15182          17.0  ...            NaN                  NaN
# 89385           NaN  ...            NaN                  NaN
# 47931           NaN  ...            NaN                  NaN
# 279085          NaN  ...            NaN                  NaN
# 7806            NaN  ...            NaN                  NaN
#
#         p_total_duration  support_feedback_avg  feedback_avg_d1  \
# id
# 15182                NaN                   4.0              5.0
# 89385                NaN                   NaN              NaN
# 47931                NaN                   NaN              NaN
# 279085               NaN                   NaN              NaN
# 7806                 NaN                   NaN              5.0
#
#         feedback_avg_d2  feedback_avg_d3  feedback_avg_d4  feedback_avg_d5  \
# id
# 15182               NaN              NaN              NaN              NaN
# 89385               NaN              NaN              NaN              NaN
# 47931               NaN              NaN              NaN              NaN
# 279085              NaN              NaN              NaN              NaN
# 7806                NaN              NaN              NaN              NaN
#
#         target
# id
# 15182        0
# 89385        0
# 47931        0
# 279085       0
# 7806         0
#
# [5 rows x 58 columns]

# %%
train.target.value_counts()
# Out:
# 0    174301
# 1     13512
# 5      3678
# 4      3659
# 3      3027
# 2      1823
# Name: target, dtype: int64

# %%
train.target.unique()
# Out:
# array([0, 3, 1, 4, 5, 2], dtype=int64)

# %%
# %%time

test= pd.read_csv('test_dataset_test.csv', parse_dates=['month_id','carts_created_at'], index_col='id')
test.head()
# Out:
# Wall time: 363 ms
#         age_indicator   month_id  student_id  program_id carts_created_at  \
# id
# 77551             NaN 2021-05-31     7064806        1395       2021-02-28
# 227812           27.0 2021-05-31     6982061         245       2021-01-01
# 103035            9.0 2021-06-30     7118790        1233       2021-03-19
# 260943            NaN 2021-09-30     7288419         784       2021-06-29
# 134611            7.0 2021-08-31     6949976         998       2020-12-31
#
#         spent_time_total  spent_time_to_complete_hw  completed_hw  failed_hw  \
# id
# 77551                NaN                        NaN           NaN        NaN
# 227812              81.0                        0.0           5.0        0.0
# 103035              49.0                        0.0           2.0        0.0
# 260943              10.0                        NaN           0.0        0.0
# 134611               NaN                        NaN           NaN        NaN
#
#         reworked_hw  ...  p_missed_calls  p_total_calls  p_was_conversations  \
# id                   ...
# 77551           NaN  ...             NaN            NaN                  NaN
# 227812         13.0  ...             NaN            NaN                  NaN
# 103035          0.0  ...             NaN            NaN                  NaN
# 260943          0.0  ...             0.0            2.0                  2.0
# 134611          NaN  ...             NaN            NaN                  NaN
#
#         p_total_duration  support_feedback_avg  feedback_avg_d1  \
# id
# 77551                NaN                   NaN              NaN
# 227812               NaN                   NaN              NaN
# 103035               NaN                   NaN              NaN
# 260943              61.0                   NaN              NaN
# 134611               NaN                   NaN              NaN
#
#         feedback_avg_d2  feedback_avg_d3  feedback_avg_d4  feedback_avg_d5
# id
# 77551               NaN              NaN              NaN              NaN
# 227812              NaN              NaN              NaN              NaN
# 103035              NaN              5.0              NaN              NaN
# 260943              NaN              NaN              NaN              NaN
# 134611              NaN              NaN              NaN              NaN
#
# [5 rows x 57 columns]

# %%
sample_submisson = pd.read_csv('sample_solution.csv', index_col='id')
sample_submisson.head()
# Out:
#         target
# id
# 77551        0
# 227812       0
# 103035       0
# 260943       0
# 134611       0

# %%
test = pd.merge(test, sample_submisson, how='left', on='id')
test.head()
# Out:
#         age_indicator   month_id  student_id  program_id carts_created_at  \
# id
# 77551             NaN 2021-05-31     7064806        1395       2021-02-28
# 227812           27.0 2021-05-31     6982061         245       2021-01-01
# 103035            9.0 2021-06-30     7118790        1233       2021-03-19
# 260943            NaN 2021-09-30     7288419         784       2021-06-29
# 134611            7.0 2021-08-31     6949976         998       2020-12-31
#
#         spent_time_total  spent_time_to_complete_hw  completed_hw  failed_hw  \
# id
# 77551                NaN                        NaN           NaN        NaN
# 227812              81.0                        0.0           5.0        0.0
# 103035              49.0                        0.0           2.0        0.0
# 260943              10.0                        NaN           0.0        0.0
# 134611               NaN                        NaN           NaN        NaN
#
#         reworked_hw  ...  p_total_calls  p_was_conversations  \
# id                   ...
# 77551           NaN  ...            NaN                  NaN
# 227812         13.0  ...            NaN                  NaN
# 103035          0.0  ...            NaN                  NaN
# 260943          0.0  ...            2.0                  2.0
# 134611          NaN  ...            NaN                  NaN
#
#         p_total_duration  support_feedback_avg  feedback_avg_d1  \
# id
# 77551                NaN                   NaN              NaN
# 227812               NaN                   NaN              NaN
# 103035               NaN                   NaN              NaN
# 260943              61.0                   NaN              NaN
# 134611               NaN                   NaN              NaN
#
#         feedback_avg_d2  feedback_avg_d3  feedback_avg_d4  feedback_avg_d5  \
# id
# 77551               NaN              NaN              NaN              NaN
# 227812              NaN              NaN              NaN              NaN
# 103035              NaN              5.0              NaN              NaN
# 260943              NaN              NaN              NaN              NaN
# 134611              NaN              NaN              NaN              NaN
#
#         target
# id
# 77551        0
# 227812       0
# 103035       0
# 260943       0
# 134611       0
#
# [5 rows x 58 columns]

# %%
zarplata = pd.read_excel('zp.xlsx', engine='openpyxl', index_col='index')

# %%
def make_features(data, zarplata):
    data['is_weekend'] = (data['carts_created_at'].dt.dayofweek>5).astype(int)
    data['city'] = data['city'].str.replace(r'[^\w\s]', '', regex=True)
    zarplata['city']=zarplata['city'].str.replace(r'[^\w\s]', '', regex=True)
    grouped_features = ['month_id','student_id','program_id','city','ABC','platform',\
                        'payment_type','promo','gender','speed_recall','auto_payment' ,'os','hw_leader']
    tmp = ['avg_hw_mark',
        'bought_d1',
        'bought_d2',
        'bought_d3',
        'bought_d4',
        'bought_d5',
        'webinars',
        'notes',
        'avg_quiz_result',
        'completed_hw',
        'reworked_hw',
        'lessons',
        'p_avg_duration',
        'p_avg_talk_duration',
        'p_missed_calls',
        'p_total_calls',
        'p_was_conversations',
        'p_was_conversations',
        'price',
        'm_avg_duration',
        'm_avg_talk_duration',
        'm_missed_calls',
        'm_total_calls',
        'm_was_conversations',
        'm_total_duration',
        'support_feedback_avg',
        'feedback_avg_d1',
        'feedback_avg_d2',
        'feedback_avg_d3',
        'feedback_avg_d4',
        'feedback_avg_d5',
        'activity']
    for feature in grouped_features:
        
        grouped = data.groupby(feature).agg({
            'avg_hw_mark': ['min','max','median','mean','std'],
            'bought_d1': ['min','max','median','mean','std'],
            'bought_d2': ['min','max','median','mean','std'],
            'bought_d3': ['min','max','median','mean','std'],
            'bought_d4': ['min','max','median','mean','std'],
            'bought_d5': ['min','max','median','mean','std'],
            'webinars': ['min','max','median','mean','std'],
            'notes': ['min','max','median','mean','std'],
            'avg_quiz_result': ['min','max','median','mean','std'],
            'completed_hw': ['min','max','median','mean','std'],
            'reworked_hw': ['min','max','median','mean','std'],
            'lessons': ['min','max','median','mean','std'],
            'p_avg_duration': ['min','max','median','mean','std'],
            'p_avg_talk_duration': ['min','max','median','mean','std'],
            'p_missed_calls': ['min','max','median','mean','std'],
            'p_total_calls': ['min','max','median','mean','std'],
            'p_was_conversations': ['min','max','median','mean','std'],
            'p_was_conversations': ['min','max','median','mean','std'],
            'price': ['min','max','median','mean','std'],
            'm_avg_duration': ['min','max','median','mean','std'],
            'm_avg_talk_duration': ['min','max','median','mean','std'],
            'm_missed_calls': ['min','max','median','mean','std'],
            'm_total_calls': ['min','max','median','mean','std'],
            'm_was_conversations': ['min','max','median','mean','std'],
            'm_total_duration': ['min','max','median','mean','std'],
            'support_feedback_avg':['min','max','median','mean','std'],
            'feedback_avg_d1':['min','max','median','mean','std'],
            'feedback_avg_d2':['min','max','median','mean','std'],
            'feedback_avg_d3':['min','max','median','mean','std'],
            'feedback_avg_d4':['min','max','median','mean','std'],
            'feedback_avg_d5':['min','max','median','mean','std'],
            'activity':['min','max','median','mean','std'],
        })
        grouped.columns = [feature+'_'+'_'.join(col) for col in grouped.columns.values]
        grouped = grouped.reset_index()
        data = pd.merge(data, grouped, how='left', on=feature)
        for t in tmp:
            data[t+'_'+feature+'_center_mean'] = data[t] - data[feature+'_'+t+'_mean']
    data =  pd.merge(data, zarplata, how='left',on='city')
    return data

all_data = make_features(pd.concat([train,test]),  zarplata)
train, test = all_data[:len(train)], all_data[len(train):]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200000 entries, 0 to 199999
# Columns: 2479 entries, age_indicator to feat2
# dtypes: datetime64[ns](2), float64(2359), int32(1), int64(109), object(8)
# memory usage: 3.7+ GB

# %% [markdown]
# # Step 0.5. Add new features

# %% [markdown]
# # Step 0.6. Data splitting for train-test

# %%
tr_data, te_data = train_test_split(train, 
                                     test_size=TEST_SIZE,
#                                     shuffle=False,
                                        stratify=train.target,
                                     random_state=RANDOM_STATE)
print('Data splitted. Parts sizes: tr_data = {}, te_data = {}'.format(tr_data.shape, te_data.shape))
# Out:
# Data splitted. Parts sizes: tr_data = (180000, 2479), te_data = (20000, 2479)

# %% [markdown]
# # ========= AutoML preset usage =========
#
#
# ## Step 1. Create Task

# %%
# %%time

def custom_metric(y_true, y_pred, **kwargs):
    y_pred = np.argmax(y_pred, axis=1)
    return 0.2*recall_score(y_true, y_pred, average='micro')+0.8*precision_score(y_true, y_pred, average='micro')

task = Task('multiclass', metric=custom_metric )
# Out:
# Wall time: 108 ms

# %% [markdown]
# ## Step 2. Setup columns roles

# %%
# %%time

roles = {
    'target': TARGET,
#     'drop': TARGET
    DatetimeRole(base_date=False, base_feats=True, seasonality=('y', 'm', 'd')): 'carts_created_at',
    DatetimeRole(base_date=False, base_feats=True, seasonality=('y', 'm')): 'month_id'
}
# Out:
# Wall time: 0 ns

# %% [markdown]
# ## Step 3. Create AutoML from preset and train on 80% of data

# %%
params = {
#     'n_estimators': 50000,
#     'learning_rate': 0.03,
#     'reg_alpha': 3e-4,
#     'reg_lambda': 9e-2,
#     'num_leaves': 20,
#     'subsample': 0.9,
#     'subsample_freq': 2,
#     'max_bin': 240,
    'device':'gpu'
}

# %%
features = accurate_fi[accurate_fi['Importance']>0].Feature.to_list()+TARGET

# %%
automl = TabularAutoML(task = task, 
                   timeout = TIMEOUT,
                   cpu_limit = N_THREADS,
#                 memory_limit=8,
                 general_params = {'use_algos': [['lgb','lgb_tuned']]},
                   reader_params = {'n_jobs': N_THREADS, 'cv': N_FOLDS, 'random_state': RANDOM_STATE},
                        lgb_params = {'default_params': params},
                    )
oof_pred = automl.fit_predict(tr_data, roles = roles, verbose = 4)
# Out:
# [00:18:27] Stdout logging level is DEBUG.
# [00:18:27] Task: multiclass
#
# [00:18:27] Start automl preset with listed constraints:
# [00:18:27] - time: 21600.00 seconds
# [00:18:27] - CPU: 6 cores
# [00:18:27] - memory: 16 GB
#
# [00:18:27] Train data shape: (180000, 2479)
#
# [00:25:46] Feats was rejected during automatic roles guess: []
# [00:25:49] Layer 1 train process start. Time left 21158.50 secs
# D:\Ananconda3\envs\lama\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# D:\Ananconda3\envs\lama\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
#
===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# D:\Ananconda3\envs\lama\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# D:\Ananconda3\envs\lama\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [02:37:45] Training until validation scores don't improve for 100 rounds
# [02:41:05] [100]	valid's multi_logloss: 0.128538	valid's Opt metric: 0.959333
# [02:44:02] [200]	valid's multi_logloss: 0.103931	valid's Opt metric: 0.9695
# [02:46:06] [300]	valid's multi_logloss: 0.0979184	valid's Opt metric: 0.971639
# [02:47:38] [400]	valid's multi_logloss: 0.0963116	valid's Opt metric: 0.973083
# [02:48:55] Early stopping, best iteration is:
# [397]	valid's multi_logloss: 0.0962564	valid's Opt metric: 0.973083
# [02:49:05] ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# D:\Ananconda3\envs\lama\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# D:\Ananconda3\envs\lama\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [02:49:28] Training until validation scores don't improve for 100 rounds
# [02:52:48] [100]	valid's multi_logloss: 0.129338	valid's Opt metric: 0.957222
# [02:55:43] [200]	valid's multi_logloss: 0.101725	valid's Opt metric: 0.968778
# [02:57:47] [300]	valid's multi_logloss: 0.0944804	valid's Opt metric: 0.971611
# [02:59:19] [400]	valid's multi_logloss: 0.0917191	valid's Opt metric: 0.972694
# [03:00:37] [500]	valid's multi_logloss: 0.0914842	valid's Opt metric: 0.973833
# [03:01:31] Early stopping, best iteration is:
# [483]	valid's multi_logloss: 0.0913203	valid's Opt metric: 0.973639
# [03:01:41] Fitting Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM finished. score = 0.973538888888889
# [03:01:41] Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM fitting and predicting completed
# [03:01:41] Time left 11806.20 secs
#
# [03:01:41] Time limit exceeded in one of the tasks. AutoML will blend level 1 models.
#
# [03:01:41] Layer 1 training completed.
#
# [03:01:41] Blending: optimization starts with equal weights and score 0.9725277777777779
# [03:01:43] Blending: iteration 0: score = 0.973438888888889, weights = [0.05572809 0.9442719 ]
# [03:01:45] Blending: iteration 1: score = 0.973438888888889, weights = [0.05572809 0.9442719 ]
# [03:01:45] Blending: no score update. Terminated
#
# [03:01:45] Automl preset training completed in 9797.75 seconds
#
# [03:01:45] Model description:
# Final prediction for new objects (level 0) =
# 	 0.05573 * (4 averaged models Lvl_0_Pipe_0_Mod_0_LightGBM) +
# 	 0.94427 * (5 averaged models Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM)

# %%
fast_fi = automl.get_feature_scores('fast')
# fast_fi.set_index('Feature')['Importance'].plot.bar(figsize = (30, 10), grid = True)
fast_fi
# Out:
#                                    Feature     Importance
# 0                         carts_created_at  149270.656446
# 1                     student_id_price_std   39578.865121
# 2                               student_id   27965.051557
# 3                            age_indicator   26925.326193
# 4           student_id_feedback_avg_d3_max   25299.496984
# ...                                    ...            ...
# 1493                platform_bought_d3_std       0.015247
# 1494      platform_p_avg_talk_duration_max       0.011550
# 1495  hw_leader_m_avg_talk_duration_median       0.007848
# 1496              gender_p_total_calls_std       0.006886
# 1497        hw_leader_m_total_duration_max       0.002292
#
# [1498 rows x 2 columns]

# %%
accurate_fi = automl.get_feature_scores('accurate', te_data.sample(5000), silent = False)
# Out:
# [09:24:32] LightAutoML ts master used 1009 feats
# [09:24:55] 1/1009 Calculated score for hw_leader_feedback_avg_d5_median: 0.0000000
# [09:25:06] 2/1009 Calculated score for hw_leader_bought_d1_mean: 0.0000000
# [09:25:17] 3/1009 Calculated score for platform_m_total_duration_median: 0.0000000
# [09:25:30] 4/1009 Calculated score for ABC_reworked_hw_mean: 0.0000000
# [09:25:43] 5/1009 Calculated score for student_id_p_was_conversations_min: 0.0000000
# [09:25:54] 6/1009 Calculated score for feedback_avg_d1: -0.0002000
# [09:26:07] 7/1009 Calculated score for city_activity_median: 0.0000000
# [09:26:18] 8/1009 Calculated score for hw_leader_bought_d3_max: 0.0000000
# [09:26:29] 9/1009 Calculated score for m_was_conversations: 0.0000000
# [09:26:41] 10/1009 Calculated score for ABC_m_total_duration_mean: 0.0000000
# [09:26:52] 11/1009 Calculated score for promo_m_was_conversations_mean: 0.0000000
# [09:27:03] 12/1009 Calculated score for program_id_bought_d1_mean: 0.0000000
# [09:27:15] 13/1009 Calculated score for auto_payment_m_total_calls_mean: 0.0000000
# [09:27:27] 14/1009 Calculated score for month_id_notes_mean: 0.0002000
# [09:27:38] 15/1009 Calculated score for city_webinars_min: 0.0000000
# [09:27:50] 16/1009 Calculated score for auto_payment_bought_d3_mean: 0.0000000
# [09:28:02] 17/1009 Calculated score for hw_leader_reworked_hw_max: 0.0000000
# [09:28:14] 18/1009 Calculated score for gender_price_median: 0.0000000
# [09:28:26] 19/1009 Calculated score for program_id_bought_d3_max: 0.0000000
# [09:28:38] 20/1009 Calculated score for student_id_m_total_duration_median: 0.0000000
# [09:28:49] 21/1009 Calculated score for ABC_m_total_calls_max: 0.0000000
# [09:29:01] 22/1009 Calculated score for hw_leader_p_avg_talk_duration_median: 0.0000000
# [09:29:13] 23/1009 Calculated score for platform_p_total_calls_max: 0.0000000
# [09:29:25] 24/1009 Calculated score for carts_created_at: 0.0300000
# [09:29:36] 25/1009 Calculated score for city_lessons_median: 0.0000000
# [09:29:48] 26/1009 Calculated score for gender_avg_hw_mark_mean: 0.0000000
# [09:30:00] 27/1009 Calculated score for promo_avg_hw_mark_mean: 0.0000000
# [09:30:11] 28/1009 Calculated score for program_id_p_was_conversations_mean: 0.0004000
# [09:30:23] 29/1009 Calculated score for platform_completed_hw_max: 0.0000000
# [09:30:35] 30/1009 Calculated score for auto_payment_m_missed_calls_mean: 0.0000000
# [09:30:46] 31/1009 Calculated score for city_feedback_avg_d4_max: 0.0000000
# [09:30:58] 32/1009 Calculated score for student_id_feedback_avg_d2_median: 0.0000000
# [09:31:10] 33/1009 Calculated score for gender_price_max: 0.0000000
# [09:31:22] 34/1009 Calculated score for student_id_bought_d4_median: 0.0000000
# [09:31:33] 35/1009 Calculated score for program_id_feedback_avg_d2_max: 0.0000000
# [09:31:46] 36/1009 Calculated score for hw_leader_avg_quiz_result_median: 0.0000000
# [09:31:58] 37/1009 Calculated score for hw_leader_m_total_duration_median: 0.0000000
# [09:32:10] 38/1009 Calculated score for platform_reworked_hw_mean: 0.0000000
# [09:32:22] 39/1009 Calculated score for student_id_bought_d5_max: -0.0002000
# [09:32:33] 40/1009 Calculated score for os_m_total_calls_mean: 0.0000000
# [09:32:44] 41/1009 Calculated score for ABC_completed_hw_mean: 0.0000000
# [09:32:55] 42/1009 Calculated score for hw_leader_p_missed_calls_mean: 0.0000000
# [09:33:10] 43/1009 Calculated score for program_id_p_avg_duration_mean: -0.0002000
# [09:33:31] 44/1009 Calculated score for hw_leader_feedback_avg_d1_min: 0.0000000
# [09:33:48] 45/1009 Calculated score for ABC_bought_d4_max: 0.0000000
# [09:34:05] 46/1009 Calculated score for speed_recall_avg_quiz_result_min: 0.0000000
# [09:34:21] 47/1009 Calculated score for gender_p_was_conversations_max: 0.0000000
# [09:34:38] 48/1009 Calculated score for gender_p_avg_duration_max: 0.0000000
# [09:34:54] 49/1009 Calculated score for month_id_bought_d2_max: 0.0000000
# [09:35:11] 50/1009 Calculated score for auto_payment_bought_d1_max: 0.0000000
# [09:35:26] 51/1009 Calculated score for platform_lessons_max: 0.0000000
# [09:35:42] 52/1009 Calculated score for month_id_avg_hw_mark_mean: 0.0000000
# [09:35:59] 53/1009 Calculated score for feedback_avg_d4: 0.0000000
# [09:36:17] 54/1009 Calculated score for os_m_was_conversations_max: 0.0000000
# [09:36:37] 55/1009 Calculated score for auto_payment_p_avg_duration_mean: 0.0000000
# [09:36:54] 56/1009 Calculated score for program_id_feedback_avg_d3_min: -0.0002000
# [09:37:11] 57/1009 Calculated score for month_id_completed_hw_mean: 0.0000000
# [09:37:29] 58/1009 Calculated score for promo_m_total_calls_max: 0.0000000
# [09:37:47] 59/1009 Calculated score for city_bought_d2_mean: 0.0000000
# [09:38:04] 60/1009 Calculated score for promo_feedback_avg_d1_mean: 0.0000000
# [09:38:22] 61/1009 Calculated score for ABC_notes_mean: 0.0000000
# [09:38:40] 62/1009 Calculated score for program_id_feedback_avg_d2_median: -0.0002000
# [09:38:59] 63/1009 Calculated score for os_feedback_avg_d4_mean: -0.0002000
# [09:39:17] 64/1009 Calculated score for lessons: 0.0000000
# [09:39:35] 65/1009 Calculated score for hw_leader_feedback_avg_d3_mean: 0.0000000
# [09:39:52] 66/1009 Calculated score for student_id_bought_d2_median: 0.0000000
# [09:40:10] 67/1009 Calculated score for program_id_feedback_avg_d2_mean: 0.0002000
# [09:40:28] 68/1009 Calculated score for gender_lessons_median: 0.0000000
# [09:40:45] 69/1009 Calculated score for spent_time_total: 0.0002000
# [09:41:02] 70/1009 Calculated score for promo_p_total_calls_mean: 0.0000000
# [09:41:19] 71/1009 Calculated score for platform_m_missed_calls_max: 0.0000000
# [09:41:35] 72/1009 Calculated score for auto_payment_bought_d3_max: 0.0000000
# [09:41:51] 73/1009 Calculated score for city_feedback_avg_d4_median: 0.0000000
# [09:42:07] 74/1009 Calculated score for hw_leader_p_avg_duration_min: 0.0000000
# [09:42:23] 75/1009 Calculated score for city_m_missed_calls_min: 0.0000000
# [09:42:40] 76/1009 Calculated score for gender_m_was_conversations_mean: 0.0000000
# [09:42:56] 77/1009 Calculated score for hw_leader_activity_median: 0.0000000
# [09:43:13] 78/1009 Calculated score for speed_recall_completed_hw_mean: 0.0000000
# [09:43:30] 79/1009 Calculated score for promo_reworked_hw_mean: 0.0000000
# [09:43:46] 80/1009 Calculated score for city_feedback_avg_d5_max: 0.0000000
# [09:44:03] 81/1009 Calculated score for auto_payment_m_avg_duration_median: 0.0000000
# [09:44:20] 82/1009 Calculated score for promo_m_was_conversations_median: 0.0000000
# [09:44:37] 83/1009 Calculated score for month_id_feedback_avg_d4_mean: 0.0000000
# [09:44:53] 84/1009 Calculated score for bought_avg_duration: 0.0000000
# [09:45:09] 85/1009 Calculated score for student_id_feedback_avg_d3_max: -0.0004000
# [09:45:25] 86/1009 Calculated score for platform_m_total_duration_mean: 0.0000000
# [09:45:41] 87/1009 Calculated score for auto_payment_p_avg_talk_duration_median: 0.0000000
# [09:45:58] 88/1009 Calculated score for month_id_m_missed_calls_mean: 0.0002000
# [09:46:14] 89/1009 Calculated score for city_feedback_avg_d3_median: 0.0000000
# [09:46:30] 90/1009 Calculated score for student_id_p_missed_calls_min: 0.0000000
# [09:46:42] 91/1009 Calculated score for promo_activity_median: 0.0000000
# [09:46:56] 92/1009 Calculated score for ABC_bought_d1_max: 0.0002000
# [09:47:08] 93/1009 Calculated score for gender_m_avg_talk_duration_max: 0.0000000
# [09:47:21] 94/1009 Calculated score for gender_feedback_avg_d2_min: 0.0000000
# [09:47:33] 95/1009 Calculated score for promo_feedback_avg_d5_mean: 0.0000000
# [09:47:45] 96/1009 Calculated score for platform_p_avg_talk_duration_mean: 0.0000000
# [09:47:58] 97/1009 Calculated score for hw_leader_reworked_hw_mean: 0.0000000
# [09:48:11] 98/1009 Calculated score for city_feedback_avg_d3_mean: 0.0000000
# [09:48:23] 99/1009 Calculated score for auto_payment_feedback_avg_d3_mean: 0.0000000
# [09:48:36] 100/1009 Calculated score for failed_hw: 0.0000000
# [09:48:48] 101/1009 Calculated score for program_id_bought_d5_mean: -0.0002000
# [09:49:01] 102/1009 Calculated score for os_m_total_calls_median: 0.0000000
# [09:49:13] 103/1009 Calculated score for month_id_feedback_avg_d1_median: 0.0000000
# [09:49:25] 104/1009 Calculated score for program_id_webinars_mean: -0.0008000
# [09:49:38] 105/1009 Calculated score for ABC_m_was_conversations_max: 0.0000000
# [09:49:52] 106/1009 Calculated score for hw_leader_lessons_median: 0.0000000
# [09:50:04] 107/1009 Calculated score for speed_recall_feedback_avg_d2_min: 0.0000000
# [09:50:17] 108/1009 Calculated score for auto_payment_feedback_avg_d1_median: 0.0000000
# [09:50:29] 109/1009 Calculated score for platform_m_total_duration_max: 0.0000000
# [09:50:42] 110/1009 Calculated score for price: 0.0022000
# [09:50:54] 111/1009 Calculated score for gender_m_total_duration_median: 0.0000000
# [09:51:07] 112/1009 Calculated score for auto_payment_avg_quiz_result_median: 0.0000000
# [09:51:19] 113/1009 Calculated score for promo_p_was_conversations_mean: 0.0000000
# [09:51:32] 114/1009 Calculated score for student_id_feedback_avg_d1_min: 0.0008000
# [09:51:47] 115/1009 Calculated score for city_m_total_duration_max: 0.0000000
# [09:51:59] 116/1009 Calculated score for ABC_feedback_avg_d1_mean: 0.0000000
# [09:52:12] 117/1009 Calculated score for platform_m_missed_calls_mean: 0.0000000
# [09:52:25] 118/1009 Calculated score for ABC_m_total_calls_mean: 0.0000000
# [09:52:37] 119/1009 Calculated score for program_id_feedback_avg_d4_mean: -0.0002000
# [09:52:50] 120/1009 Calculated score for is_weekend: 0.0002000
# [10:10:12] 200/1009 Calculated score for os_m_was_conversations_median: 0.0000000
# [10:10:26] 201/1009 Calculated score for student_id_p_avg_duration_min: 0.0000000
# [10:10:39] 202/1009 Calculated score for ABC_m_was_conversations_mean: 0.0000000
# [10:10:53] 203/1009 Calculated score for city_notes_mean: 0.0000000
# [10:11:06] 204/1009 Calculated score for city_bought_d3_mean: 0.0000000
# [10:11:19] 205/1009 Calculated score for speed_recall_completed_hw_max: 0.0000000
# [10:11:31] 206/1009 Calculated score for program_id_p_avg_duration_max: 0.0002000
# [10:11:44] 207/1009 Calculated score for student_id_p_total_calls_mean: 0.0000000
# [10:11:57] 208/1009 Calculated score for city_feedback_avg_d1_median: 0.0000000
# [10:12:11] 209/1009 Calculated score for platform_avg_quiz_result_median: 0.0000000
# [10:12:23] 210/1009 Calculated score for program_id_p_total_calls_min: 0.0000000
# [10:12:36] 211/1009 Calculated score for hw_leader_m_missed_calls_max: 0.0000000
# [10:12:49] 212/1009 Calculated score for city_avg_quiz_result_mean: 0.0000000
# [10:13:02] 213/1009 Calculated score for hw_leader_activity_max: 0.0000000
# [10:13:15] 214/1009 Calculated score for os_webinars_max: -0.0002000
# [10:13:28] 215/1009 Calculated score for platform_m_avg_duration_max: 0.0000000
# [10:13:41] 216/1009 Calculated score for speed_recall_feedback_avg_d2_median: 0.0000000
# [10:13:54] 217/1009 Calculated score for program_id_p_avg_talk_duration_max: -0.0002000
# [10:14:07] 218/1009 Calculated score for platform_bought_d2_max: 0.0000000
# [10:14:20] 219/1009 Calculated score for program_id_m_avg_duration_max: -0.0002000
# [10:14:33] 220/1009 Calculated score for feedback_avg_d2: -0.0002000
# [10:14:46] 221/1009 Calculated score for student_id_support_feedback_avg_min: 0.0006000
# [10:15:00] 222/1009 Calculated score for month_id_p_avg_duration_mean: 0.0010000
# [10:15:13] 223/1009 Calculated score for hw_leader_p_total_calls_mean: 0.0000000
# [10:15:26] 224/1009 Calculated score for platform_m_avg_talk_duration_mean: 0.0000000
# [10:15:39] 225/1009 Calculated score for city_m_avg_duration_min: 0.0000000
# [10:15:51] 226/1009 Calculated score for city_m_avg_talk_duration_min: 0.0000000
# [10:16:04] 227/1009 Calculated score for city_feedback_avg_d2_mean: 0.0000000
# [10:16:17] 228/1009 Calculated score for student_id_support_feedback_avg_median: 0.0010000
# [10:16:30] 229/1009 Calculated score for gender_bought_d4_mean: 0.0000000
# [10:16:43] 230/1009 Calculated score for month_id_m_was_conversations_mean: -0.0004000
# [10:16:56] 231/1009 Calculated score for city_p_avg_talk_duration_max: 0.0000000
# [10:17:09] 232/1009 Calculated score for auto_payment_p_avg_talk_duration_mean: 0.0000000
# [10:17:21] 233/1009 Calculated score for program_id_activity_median: -0.0002000
# [10:17:34] 234/1009 Calculated score for student_id_price_mean: 0.0024000
# [10:17:47] 235/1009 Calculated score for ABC_m_total_duration_max: 0.0000000
# [10:18:01] 236/1009 Calculated score for hw_leader_activity_mean: 0.0000000
# [10:18:13] 237/1009 Calculated score for ABC_p_avg_duration_min: 0.0000000
# [10:18:26] 238/1009 Calculated score for student_id_m_was_conversations_median: 0.0000000
# [10:44:01] 356/1009 Calculated score for city_m_total_calls_mean: 0.0000000
# [10:44:14] 357/1009 Calculated score for month_id_m_total_calls_max: -0.0002000
# [10:44:27] 358/1009 Calculated score for bought_d2: 0.0000000
# [10:44:40] 359/1009 Calculated score for platform_feedback_avg_d1_mean: 0.0000000
# [10:44:53] 360/1009 Calculated score for platform_p_was_conversations_median: 0.0000000
# [10:45:06] 361/1009 Calculated score for program_id_feedback_avg_d5_min: 0.0000000
# [10:45:19] 362/1009 Calculated score for payment_type_activity_max: 0.0002000
# [10:45:31] 363/1009 Calculated score for platform_feedback_avg_d3_median: 0.0000000
# [10:45:44] 364/1009 Calculated score for month_id_bought_d4_max: 0.0000000
# [10:45:57] 365/1009 Calculated score for program_id_webinars_max: -0.0004000
# [10:46:10] 366/1009 Calculated score for city_avg_quiz_result_max: 0.0000000
# [10:46:23] 367/1009 Calculated score for student_id_p_avg_duration_median: 0.0000000
# [10:46:35] 368/1009 Calculated score for promo_price_median: 0.0000000
# [10:46:48] 369/1009 Calculated score for hw_leader_feedback_avg_d2_mean: 0.0000000
# [10:47:01] 370/1009 Calculated score for student_id_price_median: 0.0052000
# [10:47:14] 371/1009 Calculated score for gender_p_total_calls_max: 0.0000000
# [10:47:27] 372/1009 Calculated score for program_id_reworked_hw_max: -0.0002000
# [10:47:39] 373/1009 Calculated score for p_total_calls: 0.0000000
# [10:47:52] 374/1009 Calculated score for city_p_avg_duration_max: 0.0000000
# [10:48:05] 375/1009 Calculated score for os_bought_d5_mean: 0.0000000
# [10:48:18] 376/1009 Calculated score for platform_feedback_avg_d5_min: 0.0000000
# [10:48:31] 377/1009 Calculated score for p_total_duration: 0.0000000
# [10:48:44] 378/1009 Calculated score for ABC_avg_hw_mark_mean: 0.0000000
# [10:48:57] 379/1009 Calculated score for gender_activity_max: 0.0000000
# [10:49:10] 380/1009 Calculated score for promo_price_mean: 0.0000000
# [10:49:22] 381/1009 Calculated score for ABC_bought_d3_max: 0.0000000
# [10:49:35] 382/1009 Calculated score for city_reworked_hw_max: 0.0000000
# [10:49:48] 383/1009 Calculated score for program_id_m_avg_talk_duration_mean: -0.0002000
# [10:50:01] 384/1009 Calculated score for program_id_m_avg_talk_duration_min: 0.0000000
# [10:50:14] 385/1009 Calculated score for program_id_m_missed_calls_max: -0.0004000
# [10:50:26] 386/1009 Calculated score for hw_leader_feedback_avg_d1_median: 0.0000000
# [10:50:39] 387/1009 Calculated score for program_id_feedback_avg_d4_median: -0.0002000
# [10:50:52] 388/1009 Calculated score for student_id_webinars_median: 0.0002000
# [10:51:05] 389/1009 Calculated score for student_id_m_missed_calls_min: 0.0000000
# [10:51:18] 390/1009 Calculated score for month_id_avg_quiz_result_min: 0.0000000
# [10:51:31] 391/1009 Calculated score for student_id_m_avg_talk_duration_max: -0.0002000
# [10:51:44] 392/1009 Calculated score for student_id_bought_d3_max: 0.0000000
# [10:51:57] 393/1009 Calculated score for ABC_price_median: 0.0000000
# [10:52:11] 394/1009 Calculated score for month_id_m_total_calls_mean: 0.0000000
# [10:52:24] 395/1009 Calculated score for student_id_bought_d3_mean: 0.0000000
# [10:52:37] 396/1009 Calculated score for program_id_bought_d3_mean: -0.0002000
# [10:52:51] 397/1009 Calculated score for program_id_p_was_conversations_max: -0.0002000
# [10:53:04] 398/1009 Calculated score for city_m_total_calls_max: 0.0000000
# [10:53:17] 399/1009 Calculated score for city_webinars_max: 0.0000000
# [10:53:31] 400/1009 Calculated score for promo_completed_hw_mean: 0.0000000
# [10:53:44] 401/1009 Calculated score for month_id_webinars_max: 0.0000000
# [10:53:58] 402/1009 Calculated score for gender_p_missed_calls_mean: 0.0000000
# [10:54:11] 403/1009 Calculated score for ABC_m_was_conversations_median: 0.0000000
# [10:54:24] 404/1009 Calculated score for promo_reworked_hw_max: 0.0000000
# [10:54:36] 405/1009 Calculated score for promo_bought_d4_mean: 0.0000000
# [10:54:49] 406/1009 Calculated score for month_id_lessons_mean: 0.0002000
# [10:55:02] 407/1009 Calculated score for ABC_avg_quiz_result_median: 0.0000000
# [10:55:15] 408/1009 Calculated score for month_id_avg_quiz_result_median: -0.0004000
# [10:55:28] 409/1009 Calculated score for platform_p_avg_talk_duration_max: 0.0000000
# [10:55:42] 410/1009 Calculated score for city_reworked_hw_median: 0.0000000
# [10:55:55] 411/1009 Calculated score for p_avg_talk_duration: 0.0000000
# [10:56:08] 412/1009 Calculated score for platform_p_avg_duration_mean: 0.0000000
# [10:56:21] 413/1009 Calculated score for speed_recall_webinars_mean: 0.0000000
# [10:56:34] 414/1009 Calculated score for hw_leader_feedback_avg_d3_max: 0.0000000
# [10:56:47] 415/1009 Calculated score for program_id_m_avg_duration_mean: 0.0002000
# [10:57:00] 416/1009 Calculated score for platform_notes_max: 0.0000000
# [10:57:12] 417/1009 Calculated score for os_price_median: 0.0000000
# [10:57:25] 418/1009 Calculated score for student_id_avg_hw_mark_min: 0.0000000
# [10:57:37] 419/1009 Calculated score for city_bought_d4_max: 0.0000000
# [10:57:50] 420/1009 Calculated score for hw_leader_bought_d5_mean: 0.0000000
# [10:58:03] 421/1009 Calculated score for student_id_feedback_avg_d2_min: 0.0000000
# [10:58:16] 422/1009 Calculated score for gender: 0.0000000
# [10:58:29] 423/1009 Calculated score for promo_bought_d1_max: 0.0000000
# [10:58:42] 424/1009 Calculated score for month_id_p_total_calls_median: 0.0002000
# [10:58:55] 425/1009 Calculated score for student_id_support_feedback_avg_mean: 0.0004000
# [10:59:08] 426/1009 Calculated score for city_price_mean: 0.0000000
# [10:59:21] 427/1009 Calculated score for auto_payment_p_was_conversations_mean: 0.0000000
# [10:59:34] 428/1009 Calculated score for hw_leader_lessons_max: 0.0000000
# [10:59:46] 429/1009 Calculated score for student_id_avg_hw_mark_median: -0.0002000
# [10:59:59] 430/1009 Calculated score for os_bought_d2_mean: 0.0000000
# [11:00:12] 431/1009 Calculated score for auto_payment_feedback_avg_d5_mean: 0.0000000
# [11:00:25] 432/1009 Calculated score for hw_leader_price_median: 0.0000000
# [11:00:38] 433/1009 Calculated score for city_m_missed_calls_median: 0.0000000
# [11:00:51] 434/1009 Calculated score for hw_leader_feedback_avg_d1_max: 0.0000000
# [11:17:44] 513/1009 Calculated score for os_p_was_conversations_max: 0.0000000
# [11:17:57] 514/1009 Calculated score for auto_payment_bought_d2_mean: 0.0000000
# [11:18:10] 515/1009 Calculated score for city_m_missed_calls_mean: 0.0000000
# [11:18:24] 516/1009 Calculated score for os_m_missed_calls_max: 0.0000000
# [11:18:37] 517/1009 Calculated score for gender_bought_d3_mean: 0.0000000
# [11:18:51] 518/1009 Calculated score for gender_support_feedback_avg_min: 0.0000000
# [11:19:03] 519/1009 Calculated score for city_notes_max: 0.0000000
# [11:19:16] 520/1009 Calculated score for hw_leader_m_avg_duration_mean: 0.0000000
# [11:19:29] 521/1009 Calculated score for gender_feedback_avg_d3_median: 0.0000000
# [11:19:41] 522/1009 Calculated score for program_id_reworked_hw_mean: 0.0000000
# [11:19:53] 523/1009 Calculated score for program_id_bought_d1_max: -0.0002000
# [11:20:05] 524/1009 Calculated score for auto_payment_bought_d1_mean: 0.0000000
# [11:20:18] 525/1009 Calculated score for os_feedback_avg_d3_median: -0.0002000
# [11:20:30] 526/1009 Calculated score for ABC_p_total_calls_median: 0.0000000
# [11:20:42] 527/1009 Calculated score for ABC_m_avg_talk_duration_max: 0.0000000
# [11:20:54] 528/1009 Calculated score for auto_payment_avg_hw_mark_mean: 0.0000000
# [11:21:07] 529/1009 Calculated score for city_m_was_conversations_min: 0.0000000
# [11:21:19] 530/1009 Calculated score for spent_time_to_complete_hw: 0.0000000
# [11:21:31] 531/1009 Calculated score for promo_m_avg_talk_duration_median: 0.0000000
# [11:21:44] 532/1009 Calculated score for ABC_support_feedback_avg_mean: 0.0000000
# [11:21:56] 533/1009 Calculated score for month_id_completed_hw_max: 0.0000000
# [11:22:08] 534/1009 Calculated score for month_id_p_total_calls_max: -0.0002000
# [11:22:21] 535/1009 Calculated score for city: 0.0000000
# [11:22:33] 536/1009 Calculated score for gender_m_avg_talk_duration_median: 0.0000000
# [11:22:46] 537/1009 Calculated score for promo_m_total_duration_median: 0.0000000
# [11:22:59] 538/1009 Calculated score for os_m_was_conversations_mean: 0.0000000
# [11:23:11] 539/1009 Calculated score for gender_feedback_avg_d4_median: 0.0000000
# [11:23:23] 540/1009 Calculated score for platform_lessons_median: 0.0000000
# [11:23:35] 541/1009 Calculated score for ABC_p_avg_duration_mean: 0.0000000
# [11:23:48] 542/1009 Calculated score for program_id_p_missed_calls_median: 0.0000000
# [11:24:00] 543/1009 Calculated score for promo: 0.0000000
# [11:24:12] 544/1009 Calculated score for student_id_m_missed_calls_mean: -0.0002000
# [11:24:25] 545/1009 Calculated score for hw_leader_feedback_avg_d1_mean: 0.0000000
# [11:24:37] 546/1009 Calculated score for city_notes_min: 0.0000000
# [11:24:48] 547/1009 Calculated score for program_id_p_was_conversations_min: 0.0000000
# [11:25:01] 548/1009 Calculated score for gender_webinars_max: 0.0000000
# [11:25:13] 549/1009 Calculated score for gender_feedback_avg_d4_mean: 0.0000000
# [11:25:25] 550/1009 Calculated score for auto_payment_m_avg_duration_mean: 0.0000000
# [11:25:37] 551/1009 Calculated score for ABC_p_avg_talk_duration_mean: 0.0000000
# [11:25:49] 552/1009 Calculated score for ABC_p_was_conversations_mean: 0.0000000
# [11:26:02] 553/1009 Calculated score for promo_bought_d2_mean: 0.0000000
# [11:26:15] 554/1009 Calculated score for program_id_p_missed_calls_max: -0.0002000
# [11:26:27] 555/1009 Calculated score for auto_payment_completed_hw_max: 0.0000000
# [11:26:40] 556/1009 Calculated score for city_feedback_avg_d2_max: 0.0000000
# [11:26:52] 557/1009 Calculated score for program_id_avg_quiz_result_max: 0.0000000
# [11:27:04] 558/1009 Calculated score for os_m_total_duration_mean: 0.0000000
# [11:27:17] 559/1009 Calculated score for os_p_avg_duration_median: 0.0000000
# [11:27:29] 560/1009 Calculated score for ABC_avg_quiz_result_mean: 0.0000000
# [11:27:41] 561/1009 Calculated score for os_support_feedback_avg_mean: 0.0000000
# [11:27:54] 562/1009 Calculated score for auto_payment_notes_mean: 0.0000000
# [11:28:06] 563/1009 Calculated score for student_id_p_avg_talk_duration_max: 0.0000000
# [11:28:18] 564/1009 Calculated score for platform_p_avg_duration_median: 0.0000000
# [11:28:30] 565/1009 Calculated score for platform_reworked_hw_max: 0.0000000
# [11:28:43] 566/1009 Calculated score for program_id_avg_quiz_result_median: -0.0004000
# [11:28:56] 567/1009 Calculated score for month_id_p_missed_calls_mean: 0.0010000
# [11:29:08] 568/1009 Calculated score for m_avg_duration: 0.0000000
# [11:29:21] 569/1009 Calculated score for program_id_p_avg_duration_median: 0.0000000
# [11:29:34] 570/1009 Calculated score for student_id_p_missed_calls_max: 0.0002000
# [11:29:46] 571/1009 Calculated score for gender_price_mean: 0.0000000
# [11:29:59] 572/1009 Calculated score for city_activity_mean: 0.0000000
# [11:30:12] 573/1009 Calculated score for gender_m_total_calls_mean: 0.0000000
# [11:30:25] 574/1009 Calculated score for ABC_feedback_avg_d4_min: 0.0000000
# [11:30:37] 575/1009 Calculated score for gender_feedback_avg_d5_min: 0.0000000
# [11:30:50] 576/1009 Calculated score for city_avg_hw_mark_min: 0.0000000
# [11:31:02] 577/1009 Calculated score for month_id_p_avg_talk_duration_mean: 0.0006000
# [11:31:15] 578/1009 Calculated score for city_avg_hw_mark_mean: 0.0000000
# [11:31:28] 579/1009 Calculated score for student_id_p_was_conversations_median: 0.0000000
# [11:31:41] 580/1009 Calculated score for platform_p_was_conversations_max: 0.0000000
# [11:31:54] 581/1009 Calculated score for city_price_median: 0.0000000
# [11:32:06] 582/1009 Calculated score for ABC_p_missed_calls_max: 0.0000000
# [11:32:19] 583/1009 Calculated score for notes: -0.0002000
# [11:32:32] 584/1009 Calculated score for promo_m_avg_duration_median: 0.0000000
# [11:32:45] 585/1009 Calculated score for month_id_bought_d1_mean: 0.0004000
# [11:32:57] 586/1009 Calculated score for gender_avg_quiz_result_mean: 0.0000000
# [11:33:10] 587/1009 Calculated score for auto_payment_bought_d5_mean: 0.0000000
# [11:33:23] 588/1009 Calculated score for city_bought_d2_max: 0.0000000
# [11:33:36] 589/1009 Calculated score for platform_bought_d5_mean: 0.0000000
# [11:33:48] 590/1009 Calculated score for student_id_p_total_calls_min: 0.0000000
# [11:34:01] 591/1009 Calculated score for os_avg_hw_mark_min: 0.0000000
# [11:34:14] 592/1009 Calculated score for platform_feedback_avg_d3_mean: 0.0000000
# [11:34:32] 593/1009 Calculated score for hw_leader_p_avg_duration_max: 0.0000000
# [11:34:49] 594/1009 Calculated score for city_feedback_avg_d1_max: 0.0000000
# [11:35:04] 595/1009 Calculated score for platform_bought_d1_max: 0.0000000
# [11:35:20] 596/1009 Calculated score for p_avg_duration: 0.0000000
# [11:35:34] 597/1009 Calculated score for student_id_p_was_conversations_mean: 0.0000000
# [11:35:49] 598/1009 Calculated score for student_id_m_total_calls_max: -0.0002000
# [11:36:01] 599/1009 Calculated score for student_id_notes_min: 0.0000000
# [11:36:12] 600/1009 Calculated score for city_feedback_avg_d5_mean: 0.0000000
# [11:36:23] 601/1009 Calculated score for city_feedback_avg_d1_min: 0.0000000
# [11:36:35] 602/1009 Calculated score for auto_payment_bought_d5_max: 0.0000000
# [11:36:46] 603/1009 Calculated score for gender_support_feedback_avg_median: 0.0000000
# [11:36:58] 604/1009 Calculated score for ABC_activity_mean: -0.0002000
# [11:37:09] 605/1009 Calculated score for hw_leader: 0.0000000
# [11:37:20] 606/1009 Calculated score for os: 0.0000000
# [11:37:31] 607/1009 Calculated score for feat1: 0.0000000
# [11:37:42] 608/1009 Calculated score for os_bought_d3_max: -0.0002000
# [11:37:54] 609/1009 Calculated score for student_id_p_total_calls_max: 0.0000000
# [11:38:05] 610/1009 Calculated score for month_id_bought_d5_mean: 0.0008000
# [11:38:16] 611/1009 Calculated score for platform_feedback_avg_d4_median: 0.0000000
# [11:38:27] 612/1009 Calculated score for program_id_price_median: 0.0000000
# [11:38:38] 613/1009 Calculated score for month_id_feedback_avg_d3_median: 0.0000000
# [11:38:50] 614/1009 Calculated score for platform_webinars_mean: 0.0000000
# ...
# [12:14:34] 808/1009 Calculated score for ABC_feedback_avg_d5_median: 0.0002000
# [12:14:45] 809/1009 Calculated score for os_avg_quiz_result_min: 0.0000000
# [12:14:56] 810/1009 Calculated score for student_id_p_avg_talk_duration_median: 0.0000000
# [12:15:08] 811/1009 Calculated score for city_feedback_avg_d4_mean: 0.0000000
# [12:15:19] 812/1009 Calculated score for platform_m_total_calls_max: 0.0000000
# [12:15:30] 813/1009 Calculated score for student_id_p_was_conversations_max: 0.0000000
# [12:15:42] 814/1009 Calculated score for program_id_p_was_conversations_median: 0.0000000
# [12:15:53] 815/1009 Calculated score for city_completed_hw_median: 0.0000000
# [12:16:04] 816/1009 Calculated score for month_id_m_avg_duration_median: 0.0000000
# [12:16:15] 817/1009 Calculated score for student_id_activity_mean: 0.0040000
# [12:16:26] 818/1009 Calculated score for os_feedback_avg_d5_mean: 0.0000000
# [12:16:37] 819/1009 Calculated score for student_id_p_avg_talk_duration_min: 0.0000000
# [12:16:48] 820/1009 Calculated score for student_id_avg_hw_mark_max: 0.0000000
# [12:17:00] 821/1009 Calculated score for ABC_p_total_calls_mean: 0.0000000
# [12:17:11] 822/1009 Calculated score for promo_m_total_calls_mean: 0.0000000
# [12:17:22] 823/1009 Calculated score for speed_recall_feedback_avg_d1_min: 0.0000000
# [12:17:33] 824/1009 Calculated score for speed_recall_m_avg_duration_mean: 0.0000000
# [12:17:45] 825/1009 Calculated score for auto_payment_bought_d4_mean: 0.0000000
# [12:17:56] 826/1009 Calculated score for city_p_was_conversations_min: 0.0000000
# [12:18:07] 827/1009 Calculated score for student_id_m_was_conversations_mean: 0.0000000
# [12:18:18] 828/1009 Calculated score for os_m_avg_duration_max: 0.0000000
# [12:18:29] 829/1009 Calculated score for gender_feedback_avg_d5_mean: 0.0000000
# [12:18:40] 830/1009 Calculated score for speed_recall_avg_hw_mark_mean: 0.0000000
# [12:18:51] 831/1009 Calculated score for city_m_total_duration_mean: 0.0000000
# [12:19:02] 832/1009 Calculated score for month_id_avg_quiz_result_mean: -0.0002000
# [12:19:13] 833/1009 Calculated score for city_p_avg_talk_duration_median: 0.0000000
# [12:19:24] 834/1009 Calculated score for hw_leader_m_total_calls_mean: 0.0000000
# [12:19:35] 835/1009 Calculated score for student_id_feedback_avg_d5_max: 0.0000000
# [12:19:46] 836/1009 Calculated score for os_completed_hw_max: 0.0000000
# [12:19:57] 837/1009 Calculated score for speed_recall_m_avg_duration_max: 0.0000000
# [12:20:08] 838/1009 Calculated score for hw_leader_m_was_conversations_max: 0.0000000
# [12:20:19] 839/1009 Calculated score for student_id_webinars_mean: 0.0004000
# [12:20:30] 840/1009 Calculated score for hw_leader_webinars_max: 0.0000000
# [12:20:41] 841/1009 Calculated score for platform_feedback_avg_d1_median: 0.0000000
# [12:20:52] 842/1009 Calculated score for os_p_avg_duration_min: 0.0000000
# [12:21:03] 843/1009 Calculated score for os_p_missed_calls_max: 0.0000000
# [12:21:14] 844/1009 Calculated score for student_id_feedback_avg_d4_median: 0.0000000
# [12:21:25] 845/1009 Calculated score for gender_feedback_avg_d2_mean: 0.0000000
# [12:21:36] 846/1009 Calculated score for month_id_reworked_hw_mean: 0.0004000
# [12:21:47] 847/1009 Calculated score for city_lessons_max: 0.0000000
# [12:21:58] 848/1009 Calculated score for platform_feedback_avg_d2_median: 0.0000000
# [12:22:09] 849/1009 Calculated score for student_id_feedback_avg_d1_mean: 0.0002000
# [12:22:20] 850/1009 Calculated score for month_id_notes_max: 0.0002000
# [12:22:32] 851/1009 Calculated score for browser: 0.0008000
# [12:22:43] 852/1009 Calculated score for p_was_conversations: -0.0002000
# [12:22:54] 853/1009 Calculated score for month_id_activity_mean: 0.0006000
# [12:23:05] 854/1009 Calculated score for bought_d1: 0.0000000
# [12:23:16] 855/1009 Calculated score for os_lessons_max: 0.0000000
# [12:23:27] 856/1009 Calculated score for program_id_avg_quiz_result_min: -0.0002000
# [12:23:38] 857/1009 Calculated score for promo_completed_hw_max: 0.0000000
# [12:23:49] 858/1009 Calculated score for speed_recall_activity_mean: 0.0000000
# [12:24:01] 859/1009 Calculated score for program_id_completed_hw_max: -0.0002000
# [12:24:12] 860/1009 Calculated score for speed_recall_lessons_mean: 0.0000000
# [12:24:23] 861/1009 Calculated score for program_id_m_was_conversations_mean: 0.0002000
# [12:24:34] 862/1009 Calculated score for student_id_avg_hw_mark_mean: -0.0002000
# [12:24:46] 863/1009 Calculated score for auto_payment_price_median: 0.0000000
# [12:24:57] 864/1009 Calculated score for auto_payment_feedback_avg_d4_mean: 0.0000000
# [12:25:08] 865/1009 Calculated score for program_id_lessons_median: 0.0000000
# [12:25:19] 866/1009 Calculated score for gender_m_was_conversations_max: 0.0000000
# [12:25:30] 867/1009 Calculated score for student_id_activity_max: 0.0004000
# [12:25:41] 868/1009 Calculated score for gender_feedback_avg_d5_median: 0.0000000
# [12:25:52] 869/1009 Calculated score for auto_payment_p_missed_calls_mean: 0.0000000
# [12:26:04] 870/1009 Calculated score for month_id_p_missed_calls_max: -0.0002000
# [12:26:15] 871/1009 Calculated score for speed_recall_notes_mean: 0.0000000
# [12:26:26] 872/1009 Calculated score for auto_payment_activity_max: 0.0000000
# [12:26:37] 873/1009 Calculated score for feat2: 0.0000000
# [12:26:48] 874/1009 Calculated score for student_id_activity_median: 0.0008000
# [12:27:00] 875/1009 Calculated score for student_id_p_missed_calls_median: 0.0000000
# [12:27:11] 876/1009 Calculated score for hw_leader_m_was_conversations_min: 0.0000000
# [12:27:22] 877/1009 Calculated score for os_m_total_duration_max: 0.0000000
# [12:27:33] 878/1009 Calculated score for os_p_total_calls_mean: 0.0000000
# [12:27:45] 879/1009 Calculated score for auto_payment_m_was_conversations_max: 0.0000000
# [12:27:56] 880/1009 Calculated score for m_total_calls: 0.0000000
# [12:28:08] 881/1009 Calculated score for promo_p_avg_duration_median: 0.0000000
# [12:28:19] 882/1009 Calculated score for gender_m_total_duration_max: 0.0000000
# [12:28:30] 883/1009 Calculated score for auto_payment_price_mean: 0.0000000
# [12:28:41] 884/1009 Calculated score for hw_leader_bought_d3_mean: 0.0000000
# [12:28:52] 885/1009 Calculated score for platform_price_min: 0.0000000
# [12:29:03] 886/1009 Calculated score for hw_leader_support_feedback_avg_min: 0.0000000
# [12:29:15] 887/1009 Calculated score for hw_leader_m_total_duration_mean: 0.0000000
# [12:29:26] 888/1009 Calculated score for ABC_feedback_avg_d3_mean: 0.0000000
# [12:29:37] 889/1009 Calculated score for city_m_total_duration_median: 0.0000000
# [12:29:48] 890/1009 Calculated score for platform_m_avg_talk_duration_median: 0.0000000
# [12:29:59] 891/1009 Calculated score for month_id_lessons_median: 0.0000000
# [12:30:11] 892/1009 Calculated score for gender_activity_mean: 0.0000000
# [12:30:22] 893/1009 Calculated score for city_m_avg_talk_duration_median: 0.0000000
# [12:30:33] 894/1009 Calculated score for gender_bought_d1_max: 0.0000000
# [12:30:46] 895/1009 Calculated score for student_id_feedback_avg_d1_median: 0.0004000
# [12:30:57] 896/1009 Calculated score for student_id_m_avg_duration_mean: -0.0008000
# [12:31:08] 897/1009 Calculated score for platform_m_avg_duration_mean: 0.0000000
# [12:31:19] 898/1009 Calculated score for program_id_feedback_avg_d1_mean: 0.0002000
# [12:31:30] 899/1009 Calculated score for test_with_good_mark: 0.0000000
# [12:31:41] 900/1009 Calculated score for os_bought_d2_max: 0.0000000
# [12:31:52] 901/1009 Calculated score for student_id_reworked_hw_mean: -0.0002000
# [12:32:04] 902/1009 Calculated score for program_id_bought_d2_max: 0.0000000
# [12:32:15] 903/1009 Calculated score for month_id_bought_d4_mean: 0.0008000
# [12:32:26] 904/1009 Calculated score for student_id_m_missed_calls_max: -0.0002000
# [12:32:37] 905/1009 Calculated score for gender_lessons_max: 0.0000000
# [12:32:48] 906/1009 Calculated score for speed_recall_feedback_avg_d3_median: 0.0000000
# [12:32:59] 907/1009 Calculated score for auto_payment_p_avg_talk_duration_max: 0.0000000
# [12:33:10] 908/1009 Calculated score for month_id_p_avg_talk_duration_median: 0.0000000
# [12:33:21] 909/1009 Calculated score for hw_leader_feedback_avg_d5_min: 0.0000000
# [12:33:32] 910/1009 Calculated score for promo_support_feedback_avg_mean: 0.0000000
# [12:33:44] 911/1009 Calculated score for hw_leader_p_was_conversations_max: 0.0000000
# [12:33:55] 912/1009 Calculated score for city_m_avg_duration_mean: 0.0000000
# [12:34:06] 913/1009 Calculated score for month_id_feedback_avg_d5_mean: 0.0000000
# [12:34:17] 914/1009 Calculated score for hw_leader_m_missed_calls_mean: 0.0000000
# [12:34:28] 915/1009 Calculated score for speed_recall_feedback_avg_d5_mean: 0.0000000
# [12:34:39] 916/1009 Calculated score for month_id_m_total_duration_mean: 0.0006000
# [12:34:50] 917/1009 Calculated score for month_id_feedback_avg_d4_median: 0.0000000
# [12:35:01] 918/1009 Calculated score for auto_payment_m_was_conversations_mean: 0.0000000
# [12:35:12] 919/1009 Calculated score for hw_leader_m_avg_duration_max: 0.0000000
# [12:35:23] 920/1009 Calculated score for auto_payment_webinars_mean: 0.0000000
# [12:35:34] 921/1009 Calculated score for os_feedback_avg_d2_min: 0.0000000
# [12:35:45] 922/1009 Calculated score for gender_reworked_hw_mean: 0.0000000
# [12:35:56] 923/1009 Calculated score for auto_payment_m_total_duration_mean: 0.0000000
# [12:36:07] 924/1009 Calculated score for platform_m_avg_duration_min: 0.0000000
# [12:36:18] 925/1009 Calculated score for program_id_p_avg_talk_duration_min: 0.0000000
# [12:36:29] 926/1009 Calculated score for platform_notes_mean: 0.0000000
# [12:36:40] 927/1009 Calculated score for os_feedback_avg_d3_min: 0.0000000
# [12:36:51] 928/1009 Calculated score for auto_payment_webinars_max: 0.0000000
# [12:37:02] 929/1009 Calculated score for platform_feedback_avg_d2_mean: 0.0000000
# [12:37:13] 930/1009 Calculated score for student_id_feedback_avg_d3_median: 0.0000000
# [12:37:24] 931/1009 Calculated score for gender_m_was_conversations_median: 0.0000000
# [12:37:35] 932/1009 Calculated score for os_m_avg_duration_min: 0.0000000
# [12:37:46] 933/1009 Calculated score for student_id_notes_mean: -0.0004000
# [12:37:57] 934/1009 Calculated score for gender_m_avg_talk_duration_mean: 0.0000000
# [12:38:08] 935/1009 Calculated score for m_total_duration: -0.0002000
# [12:38:19] 936/1009 Calculated score for program_id_p_total_calls_max: -0.0002000
# [12:38:30] 937/1009 Calculated score for ABC_m_missed_calls_max: 0.0000000
# [12:38:41] 938/1009 Calculated score for student_id_bought_d3_median: 0.0000000
# [12:38:53] 939/1009 Calculated score for city_support_feedback_avg_min: 0.0000000
# [12:39:03] 940/1009 Calculated score for promo_m_total_duration_mean: 0.0000000
# [12:39:14] 941/1009 Calculated score for city_m_missed_calls_max: 0.0000000
# [12:39:26] 942/1009 Calculated score for ABC_price_max: 0.0000000
# [12:39:37] 943/1009 Calculated score for activity: 0.0004000
# [12:39:48] 944/1009 Calculated score for promo_p_avg_talk_duration_mean: 0.0000000
# [12:39:59] 945/1009 Calculated score for os_feedback_avg_d1_median: 0.0000000
# [12:40:10] 946/1009 Calculated score for hw_leader_p_was_conversations_mean: 0.0000000
# [12:40:21] 947/1009 Calculated score for student_id_notes_max: -0.0002000
# [12:40:31] 948/1009 Calculated score for ABC_completed_hw_max: 0.0002000
# [12:40:43] 949/1009 Calculated score for hw_leader_price_max: 0.0000000
# [12:40:53] 950/1009 Calculated score for gender_p_avg_talk_duration_max: 0.0000000
# [12:41:05] 951/1009 Calculated score for month_id_activity_max: 0.0000000
# [12:41:16] 952/1009 Calculated score for city_p_avg_talk_duration_mean: 0.0000000
# [12:41:26] 953/1009 Calculated score for gender_m_total_duration_mean: 0.0000000
# [12:41:38] 954/1009 Calculated score for city_feedback_avg_d2_min: 0.0000000
# [12:41:49] 955/1009 Calculated score for ABC_m_avg_duration_mean: 0.0000000
# [12:42:00] 956/1009 Calculated score for city_p_avg_talk_duration_min: 0.0000000
# [12:42:11] 957/1009 Calculated score for city_p_total_calls_max: 0.0000000
# [12:42:23] 958/1009 Calculated score for student_id_m_avg_talk_duration_min: -0.0002000
# [12:42:34] 959/1009 Calculated score for gender_p_avg_duration_mean: 0.0000000
# [12:42:46] 960/1009 Calculated score for completed_hw: 0.0000000
# [12:42:57] 961/1009 Calculated score for platform_activity_mean: 0.0000000
# [12:43:08] 962/1009 Calculated score for gender_m_avg_duration_median: 0.0000000
# [12:43:19] 963/1009 Calculated score for student_id_feedback_avg_d3_min: -0.0002000
# [12:43:31] 964/1009 Calculated score for student_id_m_total_calls_mean: -0.0002000
# [12:43:42] 965/1009 Calculated score for gender_bought_d1_mean: 0.0000000
# [12:43:53] 966/1009 Calculated score for ABC_p_missed_calls_mean: -0.0002000
# [12:44:04] 967/1009 Calculated score for os_p_avg_duration_max: 0.0000000
# [12:44:15] 968/1009 Calculated score for os_notes_mean: 0.0000000
# [12:44:27] 969/1009 Calculated score for platform_bought_d4_mean: 0.0000000
# [12:44:37] 970/1009 Calculated score for speed_recall_activity_min: 0.0000000
# [12:44:48] 971/1009 Calculated score for city_p_was_conversations_max: 0.0000000
# [12:44:59] 972/1009 Calculated score for hw_leader_m_avg_duration_median: 0.0000000
# [12:45:10] 973/1009 Calculated score for program_id_m_missed_calls_mean: -0.0004000
# [12:45:21] 974/1009 Calculated score for payment_type: 0.0006000
# [12:45:33] 975/1009 Calculated score for student_id_bought_d2_mean: -0.0006000
# [12:45:45] 976/1009 Calculated score for month_id_p_avg_duration_median: 0.0002000
# [12:45:56] 977/1009 Calculated score for auto_payment_lessons_max: 0.0000000
# [12:46:07] 978/1009 Calculated score for program_id_completed_hw_median: 0.0000000
# [12:46:18] 979/1009 Calculated score for city_m_avg_duration_max: 0.0000000
# [12:46:29] 980/1009 Calculated score for program_id_avg_quiz_result_mean: -0.0004000
# [12:46:40] 981/1009 Calculated score for platform_completed_hw_mean: 0.0000000
# [12:46:51] 982/1009 Calculated score for speed_recall_avg_quiz_result_median: 0.0000000
# [12:47:02] 983/1009 Calculated score for student_id_m_total_calls_min: -0.0002000
# [12:47:13] 984/1009 Calculated score for promo_m_avg_talk_duration_mean: 0.0000000
# [12:47:24] 985/1009 Calculated score for platform_avg_quiz_result_mean: 0.0000000
# [12:47:35] 986/1009 Calculated score for hw_leader_feedback_avg_d3_median: 0.0000000
# [12:47:46] 987/1009 Calculated score for month_id_bought_d3_mean: 0.0008000
# [12:47:57] 988/1009 Calculated score for program_id_price_min: 0.0002000
# [12:48:08] 989/1009 Calculated score for os_p_avg_talk_duration_max: 0.0000000
# [12:48:19] 990/1009 Calculated score for age_indicator: 0.0020000
# [12:48:30] 991/1009 Calculated score for bought_d5: 0.0000000
# [12:48:41] 992/1009 Calculated score for student_id_m_was_conversations_min: 0.0000000
# [12:48:52] 993/1009 Calculated score for student_id_m_missed_calls_median: 0.0000000
# [12:49:03] 994/1009 Calculated score for promo_notes_mean: 0.0000000
# [12:49:13] 995/1009 Calculated score for promo_lessons_mean: 0.0000000
# [12:49:25] 996/1009 Calculated score for promo_lessons_max: 0.0000000
# [12:49:35] 997/1009 Calculated score for os_feedback_avg_d3_mean: 0.0000000
# [12:49:46] 998/1009 Calculated score for month_id_p_was_conversations_max: 0.0002000
# [12:49:58] 999/1009 Calculated score for ABC_notes_max: 0.0000000
# [12:50:08] 1000/1009 Calculated score for os_completed_hw_median: 0.0000000
# [12:50:19] 1001/1009 Calculated score for os_m_avg_talk_duration_max: 0.0000000
# [12:50:30] 1002/1009 Calculated score for city_feedback_avg_d1_mean: 0.0000000
# [12:50:41] 1003/1009 Calculated score for student_id: 0.0088000
# [12:50:52] 1004/1009 Calculated score for ABC_avg_quiz_result_min: 0.0000000
# [12:51:03] 1005/1009 Calculated score for gender_completed_hw_max: 0.0000000
# [12:51:14] 1006/1009 Calculated score for student_id_feedback_avg_d5_median: -0.0002000
# [12:51:25] 1007/1009 Calculated score for ABC_bought_d4_mean: 0.0000000
# [12:51:36] 1008/1009 Calculated score for month_id_m_avg_talk_duration_mean: 0.0002000
# [12:51:47] 1009/1009 Calculated score for gender_p_missed_calls_max: 0.0000000

# %%
features=accurate_fi[accurate_fi['Importance']>0].Feature.to_list()

# %%
automl = TabularUtilizedAutoML(task = task, 
                   timeout = TIMEOUT,
                   cpu_limit = N_THREADS,
#                 memory_limit=8,
                 general_params = {'use_algos': [['lgb','lgb_tuned']]},
                   reader_params = {'n_jobs': N_THREADS, 'cv': N_FOLDS, 'random_state': RANDOM_STATE},
                        lgb_params = {'default_params': params},
                              )
oof_pred = automl.fit_predict(train[list((set(features)))], roles = roles, verbose = 4)
# Out:
# [23:53:01] Start automl utilizator with listed constraints:
# [23:53:01] - time: 21600.00 seconds
# [23:53:01] - CPU: 6 cores
# [23:53:01] - memory: 16 GB
#
# [23:53:01] If one preset completes earlier, next preset configuration will be started
#
# [23:53:01] ==================================================
# [23:53:01] Start 0 automl preset configuration:
# [23:53:01] D:\Ananconda3\envs\lama\lib\site-packages\lightautoml\automl\presets\tabular_configs\conf_0_sel_type_0.yml, random state: {'reader_params': {'random_state': 42}, 'general_params': {'return_all_predictions': False}}
# [23:53:01] Found reader_params in kwargs, need to combine
# [23:53:01] Merged variant for reader_params = {'n_jobs': 6, 'cv': 5, 'random_state': 42}
# [23:53:01] Found general_params in kwargs, need to combine
# [23:53:01] Merged variant for general_params = {'use_algos': [['lgb', 'lgb_tuned']], 'return_all_predictions': False}
# [23:53:01] Stdout logging level is DEBUG.
# [23:53:01] Task: multiclass
#
# [23:53:01] Start automl preset with listed constraints:
# [23:53:01] - time: 21599.99 seconds
# [23:53:01] - CPU: 6 cores
# [23:53:01] - memory: 16 GB
#
# [23:53:01] Train data shape: (200000, 100)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Ananconda3\envs\lama\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'target'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_105072/3096755243.py in <module>
#       7                         lgb_params = {'default_params': params},
#       8                               )
# ----> 9 oof_pred = automl.fit_predict(train[list((set(features)))], roles = roles, verbose = 4)
#
# D:\Ananconda3\envs\lama\lib\site-packages\lightautoml\addons\utilization\utilization.py in fit_predict(self, train_data, roles, train_features, cv_iter, valid_data, valid_features, verbose, log_file)
#     310                 )
#     311
# --> 312                 val_pred = automl.fit_predict(
#     313                     train_data,
#     314                     roles,
#
# D:\Ananconda3\envs\lama\lib\site-packages\lightautoml\automl\presets\tabular_presets.py in fit_predict(self, train_data, roles, train_features, cv_iter, valid_data, valid_features, log_file, verbose)
#     547             data, _ = read_data(valid_data, valid_features, self.cpu_limit, self.read_csv_params)
#     548
# --> 549         oof_pred = super().fit_predict(train, roles=roles, cv_iter=cv_iter, valid_data=valid_data, verbose=verbose)
#     550
#     551         return cast(NumpyDataset, oof_pred)
#
# D:\Ananconda3\envs\lama\lib\site-packages\lightautoml\automl\presets\base.py in fit_predict(self, train_data, roles, train_features, cv_iter, valid_data, valid_features, verbose)
#     203
#     204         self.timer.start()
# --> 205         result = super().fit_predict(
#     206             train_data,
#     207             roles,
#
# D:\Ananconda3\envs\lama\lib\site-packages\lightautoml\automl\base.py in fit_predict(self, train_data, roles, train_features, cv_iter, valid_data, valid_features, verbose)
#     178         set_stdout_level(verbosity_to_loglevel(verbose))
#     179         self.timer.start()
# --> 180         train_dataset = self.reader.fit_read(train_data, train_features, roles)
#     181
#     182         assert (
#
# D:\Ananconda3\envs\lama\lib\site-packages\lightautoml\reader\base.py in fit_read(self, train_data, features_names, roles, **kwargs)
#     305                 else:
#     306                     self._used_array_attrs[attrs_dict[r.name]] = feat
# --> 307                     kwargs[attrs_dict[r.name]] = train_data.loc[:, feat]
#     308                 r = DropRole()
#     309
#
# D:\Ananconda3\envs\lama\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# D:\Ananconda3\envs\lama\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1042     def _getitem_tuple(self, tup: Tuple):
#    1043         try:
# -> 1044             return self._getitem_lowerdim(tup)
#    1045         except IndexingError:
#    1046             pass
#
# D:\Ananconda3\envs\lama\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     784                 # We don't need to check for tuples here because those are
#     785                 #  caught by the _is_nested_tuple_indexer check above.
# --> 786                 section = self._getitem_axis(key, axis=i)
#     787
#     788                 # We should never have a scalar section here, because
#
# D:\Ananconda3\envs\lama\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# D:\Ananconda3\envs\lama\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# D:\Ananconda3\envs\lama\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3483
#    3484         if axis == 1:
# -> 3485             return self[key]
#    3486
#    3487         self._consolidate_inplace()
#
# D:\Ananconda3\envs\lama\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# D:\Ananconda3\envs\lama\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'target'

# %%
class_mapping = automl.outer_pipes[0].ml_algos[0].models[0][0].reader.class_mapping

# %%
pred = automl.predict(test)
pred = [class_mapping[i] for i in np.argmax(pred.data[:], axis=1)]

# %%
test[TARGET] = pred
test[TARGET].value_counts()
# Out:
# C:\Users\vkrin\AppData\Local\Temp/ipykernel_105072/1374545472.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[TARGET] = pred
# D:\Ananconda3\envs\lama\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# target
# 0         75053
# 1          5498
# 4          1410
# 5          1278
# 3          1192
# 2           566
# dtype: int64

# %%
pd.DataFrame(pred, index=sample_submisson.index, columns=[TARGET]).to_csv('sub.csv')
